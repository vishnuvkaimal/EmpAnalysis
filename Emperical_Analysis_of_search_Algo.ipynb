# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import random
import time
 
def linearSearch(arr, x):
 
    start = time.perf_counter()
 
    for i in range(len(arr)):
        if arr[i] == x:
            end = time.perf_counter()
            return end
    end = time.perf_counter()
 
    return end
 
linear_search = []
time_linear_search = []
n = []
for j in range(0, 3):
 
    x = int(input("Please enter the value of n : "))
    n.append(x)
 
    for i in range(x):
        for i in range(random.randint(0, 1000)):
            linear_search.append(i)
 
    time_linear_search.append(linearSearch(linear_search, random.randint(0, x)))
    print(time_linear_search)
 
fig = go.Figure(data=go.Scatter(x=n, y=time_linear_search))
fig.update_layout(title='Emperical Analysis of linear_search',xaxis_title='Value of n',yaxis_title='Time')
fig.show()
# Out:
# Please enter the value of n : 100
# [3486.451931909]
# Please enter the value of n : 1000
# [3486.451931909, 3492.96185483]
# Please enter the value of n : 10000
# [3486.451931909, 3492.96185483, 3496.865992705]
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="fb0c24e2-8f72-4400-b79f-d5dc5e996ea9" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
# ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import random
import time
 
def linearSearch(arr, x):
 
    start = time.perf_counter()
 
    for i in range(len(arr)):
        if arr[i] == x:
            end = time.perf_counter()
            return end
    end = time.perf_counter()
 
    return end
 
def binary_search(item_list, item):
    start = time.perf_counter()
 
    first = 0
    last = len(item_list)-1
    found = False
    while(first <= last and not found):
        mid = (first + last)//2
        if item_list[mid] == item:
            found = True
        else:
            if item < item_list[mid]:
                last = mid - 1
            else:
                first = mid + 1
                
    
    return time.perf_counter()
 
fig = go.Figure()
 
search = []
time_search = []
bin_search = []
time_search_bin = []
n = []
for j in range(0, 3):
 
    x = int(input("Please enter the value of n : "))
    n.append(x)
 
    for i in range(x):
        for i in range(random.randint(0, 1000)):
            search.append(i)
 
    time_search.append(linearSearch(
        search, random.randint(0, x)))
    
    for i in range(x):
            for i in range(random.randint(0, 1000)):
                bin_search.append(i)
 
    time_search_bin.append(binary_search(
        bin_search, random.randint(0, x)))   
 
fig.add_trace(go.Scatter(x=n, y=time_search , name='Linear'))
fig.add_trace(go.Scatter(x=n, y=time_search_bin , name='Binary'))
 
fig.update_layout(title='Emperical Analysis of binary_search and linear',
                  xaxis_title='Value of n',
                  yaxis_title='Time')
fig.show()
# Out:
# Please enter the value of n : 10
# Please enter the value of n : 100
# Please enter the value of n : 1000
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="9f375449-1973-482c-bc3a-cb13bd998481" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("9f375449-1973-482c-bc3a-cb13bd998481")) {
#                     Plotly.newPlot(
# ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import random
import time
 
def bubble_sort(elements):
    start = time.perf_counter()
 
    for n in range(len(elements)-1, 0, -1):
        for i in range(n):
            if elements[i] > elements[i + 1]:
                elements[i], elements[i + 1] = elements[i + 1], elements[i]
    end = time.perf_counter()
 
    return end-start
 
def selection_sort(array):
    start = time.perf_counter()
 
       
    for step in range(len(array)):
        min_idx = step
 
        for i in range(step + 1, len(array)):
         
            # to sort in descending order, change > to < in this line
            # select the minimum element in each loop
            if array[i] < array[min_idx]:
                min_idx = i
         
        # put min at the correct position
        (array[step], array[min_idx]) = (array[min_idx], array[step])
        
    end = time.perf_counter()
    
    return end-start
 
def insertion_sort(arr):
    start = time.perf_counter()
 
    for i in range(1, len(arr)):
  
        key = arr[i]
        j = i-1
        while j >=0 and key < arr[j] :
                arr[j+1] = arr[j]
                j -= 1
        arr[j+1] = key
        
    end = time.perf_counter()
    
    return end-start
 
fig = go.Figure()
 
search = []
time_search_bubble = []
time_search_linear = []
time_search_insert = []
bin_search = []
time_search_bin = []
n = []
 
for j in range(0, 3):
 
    x = int(input("Please enter the value of x : "))
    n.append(x)
 
    for i in range(x):
        for i in range(random.randint(0, 100)):
            search.append(i)
 
    time_search_bubble.append(bubble_sort(
        search))
    
    time_search_linear.append(selection_sort(
        search))
    
    time_search_insert.append(insertion_sort(
        search))
    
    
    
 
fig.add_trace(go.Scatter(x=n, y=time_search_bubble , name='Bubble'))
fig.add_trace(go.Scatter(x=n, y=time_search_linear , name='Linear'))
fig.add_trace(go.Scatter(x=n, y=time_search_insert , name='Insert'))


 
fig.update_layout(title='Emperical Analysis of Bubble , Selection , Insertion Sort',
                  xaxis_title='Value of x',
                  yaxis_title='Time')
 
fig.show()
# Out:
# Please enter the value of x : 50
# Please enter the value of x : 100
# Please enter the value of x : 150
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="d9be57da-730a-496b-b5c5-0ff25b6826e3" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("d9be57da-730a-496b-b5c5-0ff25b6826e3")) {
#                     Plotly.newPlot(
# ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import random
import time
# Function to do bubble sort on the received list.
 
def BubbleSort(elements):
    start = time.perf_counter()
 
    for n in range(len(elements)-1, 0, -1):
        for i in range(n):
            if elements[i] > elements[i + 1]:
                elements[i], elements[i + 1] = elements[i + 1], elements[i]
    end = time.perf_counter()
 
    return end-start
 
# Function to do selection sort on the received list.
 
def SelectionSort(array):
    start = time.perf_counter()
 
    for step in range(len(array)):
        min_idx = step
 
        for i in range(step + 1, len(array)):
 
            # to sort in descending order, change > to < in this line
            # select the minimum element in each loop
            if array[i] < array[min_idx]:
                min_idx = i
 
        # put min at the correct position
        (array[step], array[min_idx]) = (array[min_idx], array[step])
 
    end = time.perf_counter()
 
    return end-start
 
# Function to do insertion sort on the received list.
 
def InsertionSort(arr):
    start = time.perf_counter()
 
    for i in range(1, len(arr)):
 
        key = arr[i]
        j = i-1
        while j >= 0 and key < arr[j]:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key
 
    end = time.perf_counter()
 
    return end-start
 
fig = go.Figure()
 
# Declaring the necessary variables
 
search = []
time_search_bubble = []
time_search_linear = []
time_search_insert = []
bin_search = []
time_search_bin = []
n = []
 
for j in range(0, 3):
    x = int(input("Please enter the value of x : "))
    n.append(x)
    for i in range(x):
        for i in range(random.randint(0, 100)):
            search.append(i)
    time_search_bubble.append(BubbleSort(
        search))
    time_search_linear.append(SelectionSort(
        search))
    time_search_insert.append(InsertionSort(
        search))
# Create traces
 
fig.add_trace(go.Scatter(x=n, y=time_search_bubble,
              name='Bubble'))
fig.add_trace(go.Scatter(x=n, y=time_search_linear,
              name='Linear'))
fig.add_trace(go.Scatter(x=n, y=time_search_insert,
              name='Insert'))
 
fig.update_layout(title='Emperical Analysis of Bubble , Selection , Insertion Sort',
                  xaxis_title='Value of x',
                  yaxis_title='Time')
 
fig.show()
# Out:
# Please enter the value of x : 100
# Please enter the value of x : 150
# Please enter the value of x : 200
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="1e9c962b-e0f5-49be-816e-5c78825b5c96" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("1e9c962b-e0f5-49be-816e-5c78825b5c96")) {
#                     Plotly.newPlot(
# ...

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import random
import time
 
def linearSearch(arr, x): 
    start = time.perf_counter()
 
    for i in range(len(arr)):
        if arr[i] == x:
            end = time.perf_counter()
            return end
    end = time.perf_counter()
 
    return end-start
 
def binary_search(item_list, item):
    start = time.perf_counter()
 
    first = 0
    last = len(item_list)-1
    found = False
    while(first <= last and not found):
        mid = (first + last)//2
        if item_list[mid] == item:
            found = True
        else:
            if item < item_list[mid]:
                last = mid - 1
            else:
                first = mid + 1
                
    end = time.perf_counter()
 
    return end-start
 
fig = go.Figure()
 
search = []
time_search = []
bin_search = []
time_search_bin = []
n = []
for j in range(0, 5):
 
    x = int(input("Please enter the value of n : "))
    n.append(x)
 
    for i in range(x):
        for i in range(random.randint(0, 1000)):
            search.append(i)
 
    time_search.append(linearSearch(
        search, random.randint(0, x)))
    
    for i in range(x):
            for i in range(random.randint(0, 1000)):
                bin_search.append(i)
 
    time_search_bin.append(binary_search(
        bin_search, random.randint(0, x)))   
 
fig.add_trace(go.Scatter(x=n, y=time_search , name='Linear'))
fig.add_trace(go.Scatter(x=n, y=time_search_bin , name='Binary'))
 
fig.update_layout(title='Emperical Analysis of linear_search and binary search',
                  xaxis_title='Value of n',
                  yaxis_title='Time')
fig.show()

# %%
from plotly.subplots import make_subplots
import plotly.graph_objects as go
import random
import time

 
def bubbleSort(a):
    start = time.perf_counter()
 
    for n in range(len(a)-1, 0, -1):
        for i in range(n):
            if a[i] > a[i + 1]:
                a[i], a[i + 1] = a[i + 1], a[i]
    end = time.perf_counter()
 
    return end-start
 
def insertionSort(arr):
    start = time.perf_counter()
 
    for i in range(1, len(arr)):
 
        key = arr[i]
        j = i-1
        while j >= 0 and key < arr[j]:
            arr[j+1] = arr[j]
            j -= 1
        arr[j+1] = key
 
    end = time.perf_counter()
 
    return end-start
 
fig = go.Figure()
 

 
def selectionSort(array):
    start = time.perf_counter()
 
    for step in range(len(array)):
        min_idx = step
 
        for i in range(step + 1, len(array)):

            if array[i] < array[min_idx]:
                min_idx = i
 

        (array[step], array[min_idx]) = (array[min_idx], array[step])
 
    end = time.perf_counter()
 
    return end-start
 

 

 
listCreate = []
t_bubble = []
t_linear = []
t_insert = []


n = []
 
for j in range(0,int(input("Please enter the number of entries ? : ")) ):
    x = int(input("Please enter the value of x : "))
    n.append(x)
    for i in range(x):
        for i in range(random.randint(0, 100)):
            listCreate.append(i)
    t_bubble.append(bubbleSort(listCreate))
    t_linear.append(selectionSort(listCreate))
    t_insert.append(insertionSort(listCreate))

 
fig.add_trace(go.Scatter(x=n, y=t_bubble, name='Bubble'))
fig.add_trace(go.Scatter(x=n, y=t_linear, name='Linear'))
fig.add_trace(go.Scatter(x=n, y=t_insert, name='Insert'))
 
fig.update_layout(title='Emperical Analysis of Bubble, Selection, Insertion Sort', xaxis_title='Value of x', yaxis_title='Time')
 
fig.show()
# Out:
# Please enter the number of entries ? : 3
# Please enter the value of x : 10
# Please enter the value of x : 50
# Please enter the value of x : 100
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>
#             <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>
#                 <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-latest.min.js"></script>
#             <div id="40968c01-77bf-4cd9-9ccd-a973c8ce6f07" class="plotly-graph-div" style="height:525px; width:100%;"></div>
#             <script type="text/javascript">
#
#                     window.PLOTLYENV=window.PLOTLYENV || {};
#
#                 if (document.getElementById("40968c01-77bf-4cd9-9ccd-a973c8ce6f07")) {
#                     Plotly.newPlot(
# ...
